# %% [markdown]
# ### 필요한 라이브러리 import

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import urllib3

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# - The convolutional layers mostly have 3×3 filters and follow two simple design rules:
#     1.  for the same output feature map size, the layers have the same number of filters
#     2.  if the feature map size is halved, the number of filters is doubled so as to preserve the time complexity per layer. We perform downsampling directly by convolutional layers that have a stride of 2. The network ends with a global average pooling layer and a 1000-way fully-connected layer with softmax
#
#      Downsampling is performed by conv3 1, conv4 1, and conv5 1 with a stride of 2.

# %% [markdown]
# - Residual Network
#     The identity shortcuts $y = F(x, \{W_i\}) + x$ can be directly used when the input and output are of the same dimensions
#
#     When the dimensions increase, we consider two options:
#     1. The shortcut still performs identity mapping, with extra zero entries padded for increasing dimensions. This option introduces no extra parameter
#     2. The projection shortcut in $y = F(x, \{W_i\}) + W_ix$ is used to match dimensions (done by 1×1 convolutions). For both options, when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2. (X)

# %% [markdown]
# The operation $F + x$ is performed by a shortcut connection and element-wise addition.
# We adopt the second nonlinearity after the addition

# %% [markdown]
# - batch normalization right after each convolution and before activation
# - initialize the weights as in <K. He, X. Zhang, S. Ren, and J. Sun. Delving deep into rectifiers: Surpassing human-level performance on imagenet classification. In ICCV, 2015.> and train all plain/residual nets from scratch
# - use SGD with a mini-batch size of 256. (for ImageNet)
# - The learning rate starts from 0.1 and is divided by 10 when the error plateaus, and the models are trained for up to $60\times{10^4}$ iterations. (오바)
# - use a weight decay of 0.0001 and a momentum of 0.9.
# - do not use dropout

# %% [markdown]
# - 50-layer ResNet
#     We replace each 2-layer block in the 34-layer net with this 3-layer bottleneck block.
#         For each residual function F, we use a stack of 3 layers instead of 2.
#         The three layers are 1×1, 3×3, and 1×1 convolutions.

# %% [markdown]
# ### ResNet 기본 블록 구성하기

# %%
def conv_bn(tensor, filters, kernel_size, strides):
    output = keras.layers.Conv2D(
        filters=filters,
        kernel_size=kernel_size,
        strides=strides,
        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
        padding='same',
    )(tensor)
    return keras.layers.BatchNormalization()(output)

# %%
def build_conv1_block(tensor, filters, kernel_size, strides):
    output = conv_bn(tensor, filters, kernel_size, strides)
    output = keras.layers.ReLU()(output)
    output = keras.layers.MaxPooling2D(
        pool_size=kernel_size,
        strides=strides,
        padding='same',
    )(output)
    
    return output

# %%
def build_basic_block(tensor, channel=64, num_cnn=3, block_num=0, residual=True):
    x = tensor
    
    for cnn_num in range(num_cnn):
        shortcut = x
        
        y = conv_bn(shortcut, channel, 3, 2 if cnn_num==0 and block_num>0 else 1) # 편의상 shortcut을 입력 텐서로 활용.
        y = keras.layers.ReLU()(y)
        y = conv_bn(y, channel, 3, 1)
        
        if cnn_num==0 and block_num>0:
            shortcut = conv_bn(shortcut, channel, 1, 2)
        
        if residual:
            y = keras.layers.add([shortcut, y])

        x = keras.layers.ReLU()(y)
    return x

# %%
def build_bottleneck_block(tensor, channel=64, num_cnn=3, filters=64, block_num=0, residual=True):
    x = tensor

    for cnn_num in range(num_cnn):
        shortcut = x

        y = conv_bn(shortcut, channel, 1, 1)
        y = keras.layers.ReLU()(y)
        y = conv_bn(y, channel, 3, 2 if cnn_num==0 and block_num>0 else 1)
        y = keras.layers.ReLU()(y)
        y = conv_bn(y, channel*4, 1, 1)
        
        if cnn_num==0:
            shortcut = conv_bn(shortcut, channel*4, 1, 2 if block_num>0 else 1)
        
        if residual:
            y = keras.layers.add([shortcut, y])
        
        x = keras.layers.ReLU()(y)
    return y

# %%
def build_resnet(input_shape=(32,32,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=10,
                 residual=True, 
                 is_50=False,
                 bc=False
                ):
    
    assert len(num_cnn_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape)
    output = input_layer
    output = build_conv1_block(output, 64, 7, 2)
    
    if is_50:
        for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
            output = build_bottleneck_block(
                output,
                channel=channel,
                num_cnn=num_cnn, 
                block_num=i,
                residual=residual
        )
    else:
        for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
            output = build_basic_block(
                output,
                channel=channel,
                num_cnn=num_cnn, 
                block_num=i,
                residual=residual
        )        
    output = keras.layers.GlobalAveragePooling2D()(output)
    output = keras.layers.Dense(num_classes, activation='sigmoid' if bc else 'relu')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %% [markdown]
# ### ResNet-34, ResNet-50 Complete Model

# %%
resnet_34 = build_resnet()
resnet_34.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_9 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, 16, 16, 64)   9472        input_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_322 (BatchN (None, 16, 16, 64)   256         conv2d_322[0][0]
# __________________________________________________________________________________________________
# re_lu_296 (ReLU)                (None, 16, 16, 64)   0           batch_normalization_322[0][0]
# __________________________________________________________________________________________________
# ...

# %%
tf.keras.utils.plot_model(resnet_34, show_shapes=True, dpi=64)

# %%
resnet_50 = build_resnet(is_50=True)
resnet_50.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_10 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 16, 16, 64)   9472        input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_358 (BatchN (None, 16, 16, 64)   256         conv2d_358[0][0]
# __________________________________________________________________________________________________
# re_lu_329 (ReLU)                (None, 16, 16, 64)   0           batch_normalization_358[0][0]
# __________________________________________________________________________________________________
# ...

# %%
tf.keras.utils.plot_model(resnet_50, show_shapes=True, dpi=64)

# %% [markdown]
# ### 일반 네트워크(plain network) 만들기

# %%
# 불필요한데 노드에 구현하라고 나와서 그냥

def build_plainnet(input_shape=(224,224,3), is_50=False, bc=False):
    return build_resnet(input_shape=input_shape,
                        residual=False,
                        is_50=is_50,
                        bc=False
                       )

# %% [markdown]
# ### ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34

# %%
# 작은 데이터셋에 대해 batch size가 크면 UnboundLocalError: local variable 'logs' referenced before assignment

BATCH_SIZE = 16
EPOCH = 10

# %%
# cats vs dogs 데이터셋
# https://east-rain.github.io/docs/Deep%20Learning/tensorflow%20tutorial/image_transfer_learning_preTrained.html

urllib3.disable_warnings()

(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True,
    shuffle_files=True,
)

# %%
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
ds_train = apply_normalize_on_dataset(ds_train, is_test=False, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, is_test=False, batch_size=BATCH_SIZE)

# %%
resnet34 = build_resnet(input_shape=(224,224,3), num_classes=1, bc=True)
resnet34.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_11 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_411 (Conv2D)             (None, 112, 112, 64) 9472        input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_411 (BatchN (None, 112, 112, 64) 256         conv2d_411[0][0]
# __________________________________________________________________________________________________
# re_lu_378 (ReLU)                (None, 112, 112, 64) 0           batch_normalization_411[0][0]
# __________________________________________________________________________________________________
# ...

# %%
resnet34.compile(
    optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_34 = resnet34.fit(
    ds_train,
    steps_per_epoch=int(18610/BATCH_SIZE),
    validation_steps=int(4652/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
)
# Out:
# Epoch 1/10
# 1163/1163 [==============================] - 97s 84ms/step - loss: 0.6941 - accuracy: 0.5895 - val_loss: 0.9098 - val_accuracy: 0.5388
# Epoch 2/10
# 1163/1163 [==============================] - 98s 84ms/step - loss: 0.6257 - accuracy: 0.6540 - val_loss: 2.8897 - val_accuracy: 0.5425
# Epoch 3/10
# 1163/1163 [==============================] - 98s 84ms/step - loss: 0.5711 - accuracy: 0.7062 - val_loss: 3.2283 - val_accuracy: 0.5394
# Epoch 4/10
# 1163/1163 [==============================] - 102s 87ms/step - loss: 0.5289 - accuracy: 0.7342 - val_loss: 0.5877 - val_accuracy: 0.7065
# Epoch 5/10
# 1163/1163 [==============================] - 100s 86ms/step - loss: 0.4660 - accuracy: 0.7756 - val_loss: 0.8161 - val_accuracy: 0.6907
# Epoch 6/10
# 1163/1163 [==============================] - 102s 87ms/step - loss: 0.3903 - accuracy: 0.8206 - val_loss: 0.5049 - val_accuracy: 0.7839
# Epoch 7/10
# ...

# %%
resnet34_plain = build_resnet(input_shape=(224,224,3), num_classes=1, residual=False, bc=True)
resnet34_plain.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_12 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_447 (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_447 (Bat (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_411 (ReLU)             (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_448 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_448 (Bat (None, 56, 56, 64)        256
# ...

# %%
resnet34_plain.compile(
    optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

history_34_plain = resnet34_plain.fit(
    ds_train,
    steps_per_epoch=int(18610/BATCH_SIZE),
    validation_steps=int(4652/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
)
# Out:
# Epoch 1/10
# 1163/1163 [==============================] - 97s 84ms/step - loss: 0.7095 - accuracy: 0.5017 - val_loss: 0.8665 - val_accuracy: 0.4858
# Epoch 2/10
# 1163/1163 [==============================] - 96s 83ms/step - loss: 0.6966 - accuracy: 0.5068 - val_loss: 0.8598 - val_accuracy: 0.4681
# Epoch 3/10
# 1163/1163 [==============================] - 94s 81ms/step - loss: 0.6949 - accuracy: 0.5041 - val_loss: 0.8559 - val_accuracy: 0.5289
# Epoch 4/10
# 1163/1163 [==============================] - 94s 81ms/step - loss: 0.6945 - accuracy: 0.5045 - val_loss: 0.6976 - val_accuracy: 0.5304
# Epoch 5/10
# 1163/1163 [==============================] - 95s 81ms/step - loss: 0.6937 - accuracy: 0.5155 - val_loss: 0.6921 - val_accuracy: 0.5216
# Epoch 6/10
# 1163/1163 [==============================] - 98s 84ms/step - loss: 0.6930 - accuracy: 0.5180 - val_loss: 0.6942 - val_accuracy: 0.5035
# Epoch 7/10
# ...

# %%
resnet50 = build_resnet(input_shape=(224,224,3), num_classes=1, is_50=True, bc=True)
resnet50.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_14 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 112, 112, 64) 9472        input_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_536 (BatchN (None, 112, 112, 64) 256         conv2d_536[0][0]
# __________________________________________________________________________________________________
# re_lu_493 (ReLU)                (None, 112, 112, 64) 0           batch_normalization_536[0][0]
# __________________________________________________________________________________________________
# ...

# %%
resnet50.compile(
    optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

history_50 = resnet50.fit(
    ds_train,
    steps_per_epoch=int(18610/BATCH_SIZE),
    validation_steps=int(4652/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
)
# Out:
# Epoch 1/10
# 1163/1163 [==============================] - 300s 258ms/step - loss: 0.7193 - accuracy: 0.5895 - val_loss: 0.6336 - val_accuracy: 0.6432
# Epoch 2/10
# 1163/1163 [==============================] - 192s 165ms/step - loss: 0.6467 - accuracy: 0.6328 - val_loss: 0.6545 - val_accuracy: 0.6273
# Epoch 3/10
# 1163/1163 [==============================] - 196s 169ms/step - loss: 0.6268 - accuracy: 0.6560 - val_loss: 8.5978 - val_accuracy: 0.5205
# Epoch 4/10
# 1163/1163 [==============================] - 195s 168ms/step - loss: 0.6029 - accuracy: 0.6826 - val_loss: 0.8849 - val_accuracy: 0.5964
# Epoch 5/10
# 1163/1163 [==============================] - 196s 168ms/step - loss: 0.5630 - accuracy: 0.7138 - val_loss: 0.5497 - val_accuracy: 0.7228
# Epoch 6/10
# 1163/1163 [==============================] - 190s 163ms/step - loss: 0.5256 - accuracy: 0.7406 - val_loss: 0.7088 - val_accuracy: 0.6053
# Epoch 7/10
# ...

# %%
resnet50_plain = build_resnet(input_shape=(224,224,3), num_classes=1, residual=False, is_50=True, bc=True)
resnet50_plain.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_15 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_589 (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_589 (Bat (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_542 (ReLU)             (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_590 (Conv2D)          (None, 56, 56, 64)        4160
# _________________________________________________________________
# batch_normalization_590 (Bat (None, 56, 56, 64)        256
# ...

# %%
resnet50_plain.compile(
    optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

history_50_plain = resnet50_plain.fit(
    ds_train,
    steps_per_epoch=int(18610/BATCH_SIZE),
    validation_steps=int(4652/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
)
# Out:
# Epoch 1/10
# 1163/1163 [==============================] - 159s 137ms/step - loss: 0.7217 - accuracy: 0.5026 - val_loss: 0.7862 - val_accuracy: 0.4873
# Epoch 2/10
# 1163/1163 [==============================] - 162s 139ms/step - loss: 0.6957 - accuracy: 0.5166 - val_loss: 0.7612 - val_accuracy: 0.5091
# Epoch 3/10
# 1163/1163 [==============================] - 159s 137ms/step - loss: 0.6962 - accuracy: 0.5110 - val_loss: 0.7289 - val_accuracy: 0.4875
# Epoch 4/10
# 1163/1163 [==============================] - 158s 136ms/step - loss: 0.6936 - accuracy: 0.5249 - val_loss: 0.7009 - val_accuracy: 0.4868
# Epoch 5/10
# 1163/1163 [==============================] - 166s 143ms/step - loss: 0.6891 - accuracy: 0.5416 - val_loss: 0.6859 - val_accuracy: 0.5576
# Epoch 6/10
# 1163/1163 [==============================] - 167s 143ms/step - loss: 0.6849 - accuracy: 0.5510 - val_loss: 0.6890 - val_accuracy: 0.5369
# Epoch 7/10
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2, 1, 1)
plt.plot(history_34.history['loss'], 'r')
plt.plot(history_34_plain.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet34', 'resnet34_plain'], loc='upper left')

plt.subplot(2, 1, 2)
plt.plot(history_34.history['val_accuracy'], 'r')
plt.plot(history_34_plain.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet34', 'resnet34_plain'], loc='upper left')

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2, 1, 1)
plt.plot(history_50.history['loss'], 'r')
plt.plot(history_50_plain.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet50', 'resnet50_plain'], loc='upper left')

plt.subplot(2, 1, 2)
plt.plot(history_50.history['val_accuracy'], 'r')
plt.plot(history_50_plain.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet50', 'resnet50_plain'], loc='upper left')

plt.show()

# %% [markdown]
# EPOCH가 10일 때를 기준으로 validation accuracy는 다음과 같다.
#
# ||validation accuracy|
# |---|-------------------|
# |resnet34|0.8799|
# |resnet34_plain|0.4888|
# |resnet50|0.8209|
# |resnet50_plain|0.5123|

# %% [markdown]
# - resnet34
# stage2_1에선 downsampling이 일어나지 않고, 논문에서도 stage3_1, stage4_1, stage5_1에서만 일어난다고 했으므로, 노드 내용 중 stage2_1_short의 파라미터와 바로 연결된 batch normalization의 파라미터를 제거하면 총 파라미터의 수는 21,315,338이 된다.
#
#
# - resnet50은 resnet34에 비해 학습 시 validation accuracy가 진동하는 경향이 있다.
#
# - plain network들의 training loss 그래프를 보면, 네트워크의 깊이가 resnet 34, 50 정도로만 깊어도 학습이 어려움을 알 수 있다.
